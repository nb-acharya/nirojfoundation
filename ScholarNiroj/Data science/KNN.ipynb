# %%
# 20260618

# %% [markdown]
# ### KNN(K Nearest Neighbor)
# - Does both classification and regression tasks
# - Euclidean Distance
# - root(x2-x1)^2 + (y2-y1)^2)
# - lazy algorithm
# - Optimal  number of k(neighbor)
#
#
# #### Explanation:
# Drawing a graph where there are bunch of points of different colors. Now,we have another new point whose value needs to be predicted. Calculate the distance from that point to each and every other point(doesn't matter how many points are present there). After that, there is a value of k, till now I dont know if the value of K is something we choose or calculated by ML. <br>
# Now, for classification, the value of k is 3, it will choose the nearest 3 points and say 2 points are of category A and 1 point is of category B, so the new point category is going to be category A.<br>
# <br>
# If the value of k = 4, and the 4 points selected are in both category A and category B equally, then it will choose based on alphabetical order, so category A is selected :D <br>
#
# In order to find the value of K, we will use the elbow method: <br>
