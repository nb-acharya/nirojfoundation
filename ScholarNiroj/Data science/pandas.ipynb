# %%
import pandas as np

# %%
pd.Series([1,2,3,4,5,6])
pd.DataFrame([
    ["Hari","Kathmandu",35,"Male"],
    ["Hari","Kathmandu",35,"Male"],
    ["Hari","Kathmandu",35,"Male"],
    ["Hari","Kathmandu",35,"Male"]
])
