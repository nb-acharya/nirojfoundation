# %%
### python basics
'''
Inventor of python: Guido Van Rossum
Data types:

'''
# Out:
# '\nThis is not a comment but it is a string literal that is not assigned to any variables\n'

# %%
a = 43
print(a)
b=a
print(b)
# Out:
# 43
# 43

# %%
## list
"""
List is mutable built in data type.
"""
movies = ["Titanic","Forrest Gump","Beautiful mind","Pulp fiction","Avengers"]
movies[0:4]

#methods used in list
movies.append("Inception")
movies

movies.insert(6,"angry men")
movies
# Out:
# ['Titanic',
#  'Forrest Gump',
#  'Beautiful mind',
#  'Pulp fiction',
#  'Avengers',
#  'Inception',
#  'angry men']

# %%
'''
List comprehensions:
'''

squares = []
for x in range(10):
    squares.append(x**2)
squares

squares = [x**2 for x in range(10)]
squares
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
scores = [34,56,67,12]
#based on the score, you have to print pass or fail in another list
result = ["Pass" if s>=40 else "Fail" for s in scores]
print(result)
# Out:
# ['Fail', 'Pass', 'Pass', 'Fail']

# %%
print(len(scores))
# Out:
# 4

# %%
#coding exercise:
"""
 Write a function clean_and_sort(lst) that removes all duplicate elements from a list without changing the 
 original order of their first appearance, and then returns a separate copy of that unique list sorted in 
 descending order.
"""

def clean_and_sort(lst):
    lst = sorted(lst)
    write_pointer = 0

    for read_pointer in range(1,len(lst)):
        if lst[read_pointer] != lst[write_pointer]:
            write_pointer +=1
            lst[write_pointer] = lst[read_pointer]

    unique_lst = lst[:write_pointer + 1]
    print("the unique list is", unique_lst)
        
    
lst = [1, 3, 4, 10, 2, 15, 15, 2, 3]
clean_and_sort(lst)


def clean_and_sort(lst):
    lst = sorted(lst)
    write_pointer = 0;

    for read_pointer in range(1,len(lst):
        if lst[read_pointer] != lst[write_pointer]:
# Out:
# the unique list is [1, 2, 3, 4, 10, 15]

# %% [markdown]
# ### python dictionaries

# %%
"""
    dictionaries are used to store the data values in key value pairs.
    
"""
thisdict = {
    "student name":"niroj bajracharya",
    "student age": 28,
    "student phone number": 9871121212
}

# %%
## why to use dictionaries?
"""
1. O(1) lookup
2. natural key-value mapping real world data is often relational
"""
